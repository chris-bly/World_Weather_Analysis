# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# print(url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 1 | airai
# Processing Record 4 of Set 1 | grindavik
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | seoul
# Processing Record 7 of Set 1 | svetlaya
# Processing Record 8 of Set 1 | avarua
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | ostrovnoy
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | altay
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | talara
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | hofn
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | caravelas
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | codrington
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | tharad
# Processing Record 27 of Set 1 | severo-kurilsk
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | pangnirtung
# Processing Record 30 of Set 1 | ahipara
# Processing Record 31 of Set 1 | acarau
# Processing Record 32 of Set 1 | gudur
# Processing Record 33 of Set 1 | kharan
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | santa isabel do rio negro
# Processing Record 36 of Set 1 | broken hill
# Processing Record 37 of Set 1 | uruzgan
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | jatai
# Processing Record 40 of Set 1 | san patricio
# Processing Record 41 of Set 1 | rimouski
# Processing Record 42 of Set 1 | kahului
# Processing Record 43 of Set 1 | le port
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | skjervoy
# Processing Record 46 of Set 1 | korla
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | kudahuvadhoo
# Processing Record 50 of Set 1 | doka
# Processing Record 1 of Set 2 | agirish
# Processing Record 2 of Set 2 | burns lake
# Processing Record 3 of Set 2 | khandyga
# Processing Record 4 of Set 2 | grand gaube
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 2 | zhanakorgan
# Processing Record 8 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 2 | saint george
# Processing Record 10 of Set 2 | rio grande
# Processing Record 11 of Set 2 | mocuba
# Processing Record 12 of Set 2 | aripuana
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | kasrawad
# Processing Record 15 of Set 2 | nishihara
# Processing Record 16 of Set 2 | bom jesus da lapa
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | port alfred
# Processing Record 19 of Set 2 | bambous virieux
# Processing Record 20 of Set 2 | preobrazheniye
# Processing Record 21 of Set 2 | aklavik
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | chokurdakh
# Processing Record 24 of Set 2 | ambilobe
# Processing Record 25 of Set 2 | ushuaia
# Processing Record 26 of Set 2 | linhares
# Processing Record 27 of Set 2 | abu zabad
# Processing Record 28 of Set 2 | lebanon
# Processing Record 29 of Set 2 | maceio
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | marienburg
# Processing Record 33 of Set 2 | tasiilaq
# Processing Record 34 of Set 2 | marzuq
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | luderitz
# Processing Record 38 of Set 2 | qaanaaq
# Processing Record 39 of Set 2 | inuvik
# Processing Record 40 of Set 2 | saskylakh
# Processing Record 41 of Set 2 | cravo norte
# Processing Record 42 of Set 2 | mar del plata
# Processing Record 43 of Set 2 | aykhal
# Processing Record 44 of Set 2 | cherskiy
# Processing Record 45 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 2 | karasjok
# Processing Record 47 of Set 2 | bluff
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | harper
# Processing Record 50 of Set 2 | olean
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | nome
# Processing Record 3 of Set 3 | studena
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | olafsvik
# Processing Record 6 of Set 3 | tuatapere
# Processing Record 7 of Set 3 | cap-aux-meules
# Processing Record 8 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 3 | rawson
# Processing Record 10 of Set 3 | omboue
# Processing Record 11 of Set 3 | sars
# Processing Record 12 of Set 3 | zhangye
# Processing Record 13 of Set 3 | khatanga
# Processing Record 14 of Set 3 | the valley
# Processing Record 15 of Set 3 | ngunguru
# Processing Record 16 of Set 3 | touros
# Processing Record 17 of Set 3 | olpad
# Processing Record 18 of Set 3 | buala
# Processing Record 19 of Set 3 | vao
# Processing Record 20 of Set 3 | suez
# Processing Record 21 of Set 3 | nyimba
# Processing Record 22 of Set 3 | bredasdorp
# Processing Record 23 of Set 3 | elliot lake
# Processing Record 24 of Set 3 | sao gabriel da cachoeira
# Processing Record 25 of Set 3 | dunedin
# Processing Record 26 of Set 3 | revelstoke
# Processing Record 27 of Set 3 | arraial do cabo
# Processing Record 28 of Set 3 | thompson
# Processing Record 29 of Set 3 | manzhouli
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | atuona
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | vardo
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | abu samrah
# Processing Record 38 of Set 3 | floro
# Processing Record 39 of Set 3 | zhigansk
# Processing Record 40 of Set 3 | celestun
# Processing Record 41 of Set 3 | hilo
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | tiksi
# Processing Record 44 of Set 3 | brookhaven
# Processing Record 45 of Set 3 | kayes
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | beringovskiy
# Processing Record 48 of Set 3 | adrar
# Processing Record 49 of Set 3 | hami
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | trelew
# Processing Record 2 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | gorele
# Processing Record 6 of Set 4 | bandarbeyla
# Processing Record 7 of Set 4 | wiwili
# Processing Record 8 of Set 4 | aquiraz
# Processing Record 9 of Set 4 | upernavik
# Processing Record 10 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 4 | kruisfontein
# Processing Record 12 of Set 4 | namuac
# Processing Record 13 of Set 4 | aonla
# Processing Record 14 of Set 4 | toftir
# City not found. Skipping...
# Processing Record 15 of Set 4 | carroll
# Processing Record 16 of Set 4 | old saybrook
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | wellington
# Processing Record 20 of Set 4 | adwa
# Processing Record 21 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 4 | vostok
# Processing Record 23 of Set 4 | port blair
# Processing Record 24 of Set 4 | santa marta
# Processing Record 25 of Set 4 | norman wells
# Processing Record 26 of Set 4 | beidao
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | nelson bay
# Processing Record 29 of Set 4 | micheweni
# Processing Record 30 of Set 4 | tchibanga
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | vila velha
# Processing Record 34 of Set 4 | cabo san lucas
# Processing Record 35 of Set 4 | moree
# Processing Record 36 of Set 4 | lambarene
# Processing Record 37 of Set 4 | margate
# Processing Record 38 of Set 4 | provideniya
# Processing Record 39 of Set 4 | monrovia
# Processing Record 40 of Set 4 | mount isa
# Processing Record 41 of Set 4 | sabya
# Processing Record 42 of Set 4 | boa vista
# Processing Record 43 of Set 4 | anloga
# Processing Record 44 of Set 4 | hobart
# Processing Record 45 of Set 4 | gambela
# Processing Record 46 of Set 4 | nowy dwor gdanski
# Processing Record 47 of Set 4 | columbus
# Processing Record 48 of Set 4 | laibin
# Processing Record 49 of Set 4 | damghan
# Processing Record 50 of Set 4 | san cristobal
# Processing Record 1 of Set 5 | labuhan
# Processing Record 2 of Set 5 | moita bonita
# Processing Record 3 of Set 5 | williams lake
# Processing Record 4 of Set 5 | pabna
# Processing Record 5 of Set 5 | krutinka
# Processing Record 6 of Set 5 | islamkot
# Processing Record 7 of Set 5 | tutoia
# Processing Record 8 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 5 | bismil
# Processing Record 10 of Set 5 | kita
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | saldanha
# Processing Record 13 of Set 5 | paracatu
# Processing Record 14 of Set 5 | inhambane
# Processing Record 15 of Set 5 | novooleksiyivka
# Processing Record 16 of Set 5 | jining
# Processing Record 17 of Set 5 | arlit
# Processing Record 18 of Set 5 | mount darwin
# Processing Record 19 of Set 5 | osvaldo cruz
# Processing Record 20 of Set 5 | sao felix do xingu
# Processing Record 21 of Set 5 | carnarvon
# Processing Record 22 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 5 | nieuw amsterdam
# Processing Record 24 of Set 5 | grand-lahou
# Processing Record 25 of Set 5 | hithadhoo
# Processing Record 26 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 5 | khani
# Processing Record 28 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | bantry
# Processing Record 30 of Set 5 | charters towers
# Processing Record 31 of Set 5 | nhulunbuy
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | la orilla
# Processing Record 34 of Set 5 | rondonopolis
# Processing Record 35 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 5 | nankana sahib
# Processing Record 37 of Set 5 | gilleleje
# Processing Record 38 of Set 5 | naze
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | gallup
# Processing Record 41 of Set 5 | fort nelson
# Processing Record 42 of Set 5 | brighton
# Processing Record 43 of Set 5 | klaksvik
# Processing Record 44 of Set 5 | kavieng
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | marawi
# Processing Record 47 of Set 5 | gbarnga
# Processing Record 48 of Set 5 | banjar
# Processing Record 49 of Set 5 | mecca
# Processing Record 50 of Set 5 | norsup
# Processing Record 1 of Set 6 | nabire
# Processing Record 2 of Set 6 | cidreira
# Processing Record 3 of Set 6 | colares
# Processing Record 4 of Set 6 | aswan
# Processing Record 5 of Set 6 | wahiawa
# Processing Record 6 of Set 6 | progreso
# Processing Record 7 of Set 6 | anadyr
# Processing Record 8 of Set 6 | porto belo
# Processing Record 9 of Set 6 | manta
# Processing Record 10 of Set 6 | ponta do sol
# Processing Record 11 of Set 6 | yulara
# Processing Record 12 of Set 6 | pangkalanbuun
# Processing Record 13 of Set 6 | urengoy
# Processing Record 14 of Set 6 | sungaipenuh
# Processing Record 15 of Set 6 | ribeira grande
# Processing Record 16 of Set 6 | velasco ibarra
# Processing Record 17 of Set 6 | qaqortoq
# Processing Record 18 of Set 6 | san juan
# Processing Record 19 of Set 6 | sola
# Processing Record 20 of Set 6 | axim
# Processing Record 21 of Set 6 | sucre
# Processing Record 22 of Set 6 | maiduguri
# Processing Record 23 of Set 6 | vanavara
# Processing Record 24 of Set 6 | srednekolymsk
# Processing Record 25 of Set 6 | te anau
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | gondanglegi
# Processing Record 28 of Set 6 | bengkulu
# Processing Record 29 of Set 6 | flinders
# Processing Record 30 of Set 6 | cassilandia
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | russell
# Processing Record 33 of Set 6 | haj ve slezsku
# Processing Record 34 of Set 6 | luanda
# Processing Record 35 of Set 6 | locri
# Processing Record 36 of Set 6 | itarema
# Processing Record 37 of Set 6 | nioro
# Processing Record 38 of Set 6 | kununurra
# Processing Record 39 of Set 6 | bouna
# Processing Record 40 of Set 6 | oussouye
# Processing Record 41 of Set 6 | vinh
# Processing Record 42 of Set 6 | veraval
# Processing Record 43 of Set 6 | prado
# Processing Record 44 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 6 | tete
# Processing Record 46 of Set 6 | lengshuitan
# Processing Record 47 of Set 6 | tecoanapa
# Processing Record 48 of Set 6 | aleksandrov gay
# Processing Record 49 of Set 6 | rameswaram
# Processing Record 50 of Set 6 | mayumba
# Processing Record 1 of Set 7 | krasnyy chikoy
# Processing Record 2 of Set 7 | puerto escondido
# Processing Record 3 of Set 7 | padang
# Processing Record 4 of Set 7 | haines junction
# Processing Record 5 of Set 7 | zeya
# Processing Record 6 of Set 7 | priargunsk
# Processing Record 7 of Set 7 | puerto madryn
# Processing Record 8 of Set 7 | fontem
# Processing Record 9 of Set 7 | biltine
# Processing Record 10 of Set 7 | egvekinot
# Processing Record 11 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 7 | uinskoye
# Processing Record 15 of Set 7 | jumla
# Processing Record 16 of Set 7 | liwale
# Processing Record 17 of Set 7 | arica
# Processing Record 18 of Set 7 | andenes
# Processing Record 19 of Set 7 | waingapu
# Processing Record 20 of Set 7 | isangel
# Processing Record 21 of Set 7 | raudeberg
# Processing Record 22 of Set 7 | vegreville
# Processing Record 23 of Set 7 | zvishavane
# Processing Record 24 of Set 7 | oum hadjer
# Processing Record 25 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 7 | cockburn town
# Processing Record 28 of Set 7 | aktau
# Processing Record 29 of Set 7 | wairoa
# Processing Record 30 of Set 7 | suntar
# Processing Record 31 of Set 7 | liminangcong
# City not found. Skipping...
# Processing Record 32 of Set 7 | senj
# Processing Record 33 of Set 7 | pevek
# Processing Record 34 of Set 7 | sal rei
# Processing Record 35 of Set 7 | callaguip
# Processing Record 36 of Set 7 | tahe
# Processing Record 37 of Set 7 | quatre cocos
# Processing Record 38 of Set 7 | bodaybo
# Processing Record 39 of Set 7 | domoni
# Processing Record 40 of Set 7 | tocantinopolis
# City not found. Skipping...
# Processing Record 41 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 7 | tomohon
# Processing Record 43 of Set 7 | muret
# Processing Record 44 of Set 7 | cap malheureux
# Processing Record 45 of Set 7 | lowestoft
# Processing Record 46 of Set 7 | helena
# Processing Record 47 of Set 7 | grao mogol
# Processing Record 48 of Set 7 | lixourion
# Processing Record 49 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 50 of Set 7 | ketchikan
# Processing Record 1 of Set 8 | chanute
# Processing Record 2 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 8 | lasa
# Processing Record 4 of Set 8 | stykkisholmur
# Processing Record 5 of Set 8 | ballina
# Processing Record 6 of Set 8 | houston
# Processing Record 7 of Set 8 | bitung
# Processing Record 8 of Set 8 | nova kakhovka
# Processing Record 9 of Set 8 | lockport
# Processing Record 10 of Set 8 | namatanai
# Processing Record 11 of Set 8 | turukhansk
# Processing Record 12 of Set 8 | konza
# Processing Record 13 of Set 8 | kocerinovo
# City not found. Skipping...
# Processing Record 14 of Set 8 | sao joao da barra
# Processing Record 15 of Set 8 | whitehorse
# Processing Record 16 of Set 8 | yelizavetino
# Processing Record 17 of Set 8 | barra patuca
# Processing Record 18 of Set 8 | kalmunai
# Processing Record 19 of Set 8 | geraldton
# Processing Record 20 of Set 8 | mount gambier
# Processing Record 21 of Set 8 | portland
# Processing Record 22 of Set 8 | tairua
# Processing Record 23 of Set 8 | ancud
# Processing Record 24 of Set 8 | yuancheng
# Processing Record 25 of Set 8 | khor
# Processing Record 26 of Set 8 | imbituba
# Processing Record 27 of Set 8 | chara
# Processing Record 28 of Set 8 | moshi
# Processing Record 29 of Set 8 | haradok
# Processing Record 30 of Set 8 | khanpur
# Processing Record 31 of Set 8 | broome
# Processing Record 32 of Set 8 | lebu
# Processing Record 33 of Set 8 | saint-augustin
# Processing Record 34 of Set 8 | beatrice
# Processing Record 35 of Set 8 | skelleftea
# Processing Record 36 of Set 8 | mackenzie
# Processing Record 37 of Set 8 | woodward
# Processing Record 38 of Set 8 | nehe
# Processing Record 39 of Set 8 | jacareacanga
# Processing Record 40 of Set 8 | novikovo
# Processing Record 41 of Set 8 | trairi
# Processing Record 42 of Set 8 | rio gallegos
# Processing Record 43 of Set 8 | novotroitsk
# Processing Record 44 of Set 8 | barranca
# Processing Record 45 of Set 8 | faanui
# Processing Record 46 of Set 8 | arcata
# Processing Record 47 of Set 8 | imeni poliny osipenko
# Processing Record 48 of Set 8 | ruteng
# Processing Record 49 of Set 8 | vyartsilya
# Processing Record 50 of Set 8 | kaeo
# Processing Record 1 of Set 9 | bilibino
# Processing Record 2 of Set 9 | lorengau
# Processing Record 3 of Set 9 | port moresby
# Processing Record 4 of Set 9 | atar
# Processing Record 5 of Set 9 | mujiayingzi
# Processing Record 6 of Set 9 | chapais
# Processing Record 7 of Set 9 | bambanglipuro
# Processing Record 8 of Set 9 | alofi
# Processing Record 9 of Set 9 | alice springs
# Processing Record 10 of Set 9 | yar-sale
# Processing Record 11 of Set 9 | sitka
# Processing Record 12 of Set 9 | atambua
# Processing Record 13 of Set 9 | aitape
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | vestmannaeyjar
# Processing Record 16 of Set 9 | jidong
# Processing Record 17 of Set 9 | lincoln
# Processing Record 18 of Set 9 | urucui
# Processing Record 19 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 9 | ongole
# Processing Record 21 of Set 9 | meulaboh
# Processing Record 22 of Set 9 | houma
# Processing Record 23 of Set 9 | xuddur
# Processing Record 24 of Set 9 | lake cowichan
# Processing Record 25 of Set 9 | lar
# Processing Record 26 of Set 9 | hun
# Processing Record 27 of Set 9 | upington
# Processing Record 28 of Set 9 | little current
# Processing Record 29 of Set 9 | tukums
# Processing Record 30 of Set 9 | byron bay
# Processing Record 31 of Set 9 | smidovich
# Processing Record 32 of Set 9 | vila franca do campo
# Processing Record 33 of Set 9 | gushikawa
# Processing Record 34 of Set 9 | tshikapa
# Processing Record 35 of Set 9 | erzin
# Processing Record 36 of Set 9 | chibombo
# Processing Record 37 of Set 9 | hanzhong
# Processing Record 38 of Set 9 | severnyy
# Processing Record 39 of Set 9 | fereydun kenar
# Processing Record 40 of Set 9 | berlevag
# Processing Record 41 of Set 9 | clyde river
# Processing Record 42 of Set 9 | constantine
# Processing Record 43 of Set 9 | sarkand
# Processing Record 44 of Set 9 | vaitape
# Processing Record 45 of Set 9 | rio claro
# Processing Record 46 of Set 9 | hakvik
# City not found. Skipping...
# Processing Record 47 of Set 9 | tabou
# Processing Record 48 of Set 9 | salalah
# Processing Record 49 of Set 9 | haicheng
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | cateel
# Processing Record 2 of Set 10 | pringsewu
# Processing Record 3 of Set 10 | dillon
# Processing Record 4 of Set 10 | dudinka
# Processing Record 5 of Set 10 | okhotsk
# Processing Record 6 of Set 10 | chuy
# Processing Record 7 of Set 10 | baie-comeau
# Processing Record 8 of Set 10 | sorong
# Processing Record 9 of Set 10 | san carlos
# Processing Record 10 of Set 10 | san javier
# Processing Record 11 of Set 10 | malakal
# Processing Record 12 of Set 10 | sumbe
# Processing Record 13 of Set 10 | mayo
# Processing Record 14 of Set 10 | torbay
# Processing Record 15 of Set 10 | cairns
# Processing Record 16 of Set 10 | roma
# Processing Record 17 of Set 10 | alcazar de san juan
# Processing Record 18 of Set 10 | awjilah
# Processing Record 19 of Set 10 | bagdarin
# Processing Record 20 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 21 of Set 10 | davila
# Processing Record 22 of Set 10 | concarneau
# Processing Record 23 of Set 10 | staraya toropa
# Processing Record 24 of Set 10 | winslow
# Processing Record 25 of Set 10 | kitui
# Processing Record 26 of Set 10 | lebedyn
# Processing Record 27 of Set 10 | chamba
# Processing Record 28 of Set 10 | mkushi
# Processing Record 29 of Set 10 | honiara
# Processing Record 30 of Set 10 | iralaya
# Processing Record 31 of Set 10 | taburi
# City not found. Skipping...
# Processing Record 32 of Set 10 | fortuna
# Processing Record 33 of Set 10 | yarada
# Processing Record 34 of Set 10 | ishigaki
# Processing Record 35 of Set 10 | faya
# Processing Record 36 of Set 10 | shakawe
# Processing Record 37 of Set 10 | itapaci
# Processing Record 38 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 39 of Set 10 | carutapera
# Processing Record 40 of Set 10 | jiangyou
# Processing Record 41 of Set 10 | abbeville
# Processing Record 42 of Set 10 | prince rupert
# Processing Record 43 of Set 10 | lompoc
# Processing Record 44 of Set 10 | mantua
# Processing Record 45 of Set 10 | tommot
# Processing Record 46 of Set 10 | moose factory
# Processing Record 47 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 10 | ambon
# Processing Record 49 of Set 10 | havelock
# Processing Record 50 of Set 10 | sibolga
# Processing Record 1 of Set 11 | port macquarie
# Processing Record 2 of Set 11 | hendaye
# Processing Record 3 of Set 11 | katangli
# Processing Record 4 of Set 11 | berezovyy
# Processing Record 5 of Set 11 | turan
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | muros
# Processing Record 8 of Set 11 | husavik
# Processing Record 9 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 11 | cerritos
# Processing Record 11 of Set 11 | acajutla
# Processing Record 12 of Set 11 | dinsor
# City not found. Skipping...
# Processing Record 13 of Set 11 | malumfashi
# Processing Record 14 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 11 | paamiut
# Processing Record 16 of Set 11 | freeport
# Processing Record 17 of Set 11 | carballo
# Processing Record 18 of Set 11 | yeppoon
# Processing Record 19 of Set 11 | amalfi
# Processing Record 20 of Set 11 | svetlyy
# Processing Record 21 of Set 11 | palana
# Processing Record 22 of Set 11 | pleshanovo
# Processing Record 23 of Set 11 | stephenville
# Processing Record 24 of Set 11 | hemel hempstead
# Processing Record 25 of Set 11 | bonthe
# Processing Record 26 of Set 11 | san luis potosi
# Processing Record 27 of Set 11 | mulchen
# Processing Record 28 of Set 11 | ugoofaaru
# Processing Record 29 of Set 11 | puyang
# Processing Record 30 of Set 11 | half moon bay
# Processing Record 31 of Set 11 | rocha
# Processing Record 32 of Set 11 | almaznyy
# Processing Record 33 of Set 11 | praia da vitoria
# Processing Record 34 of Set 11 | katima mulilo
# Processing Record 35 of Set 11 | kosa
# Processing Record 36 of Set 11 | coihaique
# Processing Record 37 of Set 11 | birao
# Processing Record 38 of Set 11 | parabel
# Processing Record 39 of Set 11 | kurgan
# Processing Record 40 of Set 11 | ixtapa
# Processing Record 41 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 11 | lagoa
# Processing Record 43 of Set 11 | dauphin
# Processing Record 44 of Set 11 | tura
# Processing Record 45 of Set 11 | tokonou
# Processing Record 46 of Set 11 | shaunavon
# Processing Record 47 of Set 11 | tateyama
# Processing Record 48 of Set 11 | pinheiro machado
# Processing Record 49 of Set 11 | yerbogachen
# Processing Record 50 of Set 11 | sept-iles
# Processing Record 1 of Set 12 | iqaluit
# Processing Record 2 of Set 12 | kawalu
# Processing Record 3 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 12 | lavrentiya
# Processing Record 5 of Set 12 | san borja
# Processing Record 6 of Set 12 | ha giang
# Processing Record 7 of Set 12 | la romana
# Processing Record 8 of Set 12 | west bay
# Processing Record 9 of Set 12 | comarapa
# Processing Record 10 of Set 12 | lagoa vermelha
# Processing Record 11 of Set 12 | taoudenni
# Processing Record 12 of Set 12 | oktyabrskiy
# Processing Record 13 of Set 12 | penzance
# Processing Record 14 of Set 12 | dakar
# Processing Record 15 of Set 12 | lokosovo
# Processing Record 16 of Set 12 | vilyuysk
# Processing Record 17 of Set 12 | sale
# Processing Record 18 of Set 12 | samarai
# Processing Record 19 of Set 12 | udachnyy
# Processing Record 20 of Set 12 | saint-leu
# Processing Record 21 of Set 12 | sao jose da coroa grande
# Processing Record 22 of Set 12 | grants pass
# Processing Record 23 of Set 12 | de-kastri
# Processing Record 24 of Set 12 | port augusta
# Processing Record 25 of Set 12 | ilulissat
# Processing Record 26 of Set 12 | media luna
# Processing Record 27 of Set 12 | eyl
# Processing Record 28 of Set 12 | angarsk
# Processing Record 29 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 12 | lop buri
# Processing Record 31 of Set 12 | gat
# Processing Record 32 of Set 12 | poya
# Processing Record 33 of Set 12 | xuchang
# Processing Record 34 of Set 12 | shache
# Processing Record 35 of Set 12 | matay
# Processing Record 36 of Set 12 | krasnoobsk
# Processing Record 37 of Set 12 | linxia
# Processing Record 38 of Set 12 | sabang
# Processing Record 39 of Set 12 | gambo
# Processing Record 40 of Set 12 | kabalo
# Processing Record 41 of Set 12 | malpe
# Processing Record 42 of Set 12 | ndioum
# Processing Record 43 of Set 12 | san antonio
# Processing Record 44 of Set 12 | karema
# Processing Record 45 of Set 12 | poronaysk
# Processing Record 46 of Set 12 | brae
# Processing Record 47 of Set 12 | avon lake
# Processing Record 48 of Set 12 | hualmay
# Processing Record 49 of Set 12 | fare
# Processing Record 50 of Set 12 | noumea
# Processing Record 1 of Set 13 | pacific grove
# Processing Record 2 of Set 13 | hiroshima
# Processing Record 3 of Set 13 | lisakovsk
# Processing Record 4 of Set 13 | caconda
# Processing Record 5 of Set 13 | sabha
# Processing Record 6 of Set 13 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 13 | barbacoas
# Processing Record 8 of Set 13 | ararat
# Processing Record 9 of Set 13 | taylor
# Processing Record 10 of Set 13 | mbuyapey
# Processing Record 11 of Set 13 | saurimo
# Processing Record 12 of Set 13 | inta
# Processing Record 13 of Set 13 | walvis bay
# Processing Record 14 of Set 13 | san carlos de bariloche
# Processing Record 15 of Set 13 | bonavista
# Processing Record 16 of Set 13 | kloulklubed
# Processing Record 17 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 13 | sorland
# Processing Record 19 of Set 13 | yuzhno-kurilsk
# Processing Record 20 of Set 13 | nouadhibou
# Processing Record 21 of Set 13 | lovec
# City not found. Skipping...
# Processing Record 22 of Set 13 | goure
# Processing Record 23 of Set 13 | palmer
# Processing Record 24 of Set 13 | miyako
# Processing Record 25 of Set 13 | stokmarknes
# Processing Record 26 of Set 13 | lata
# Processing Record 27 of Set 13 | bousso
# Processing Record 28 of Set 13 | akhisar
# Processing Record 29 of Set 13 | boyolangu
# Processing Record 30 of Set 13 | moissala
# Processing Record 31 of Set 13 | rio verde de mato grosso
# Processing Record 32 of Set 13 | mehamn
# Processing Record 33 of Set 13 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 13 | tiznit
# Processing Record 36 of Set 13 | ozinki
# Processing Record 37 of Set 13 | dalbandin
# Processing Record 38 of Set 13 | muravlenko
# Processing Record 39 of Set 13 | ko samui
# Processing Record 40 of Set 13 | halifax
# Processing Record 41 of Set 13 | praya
# Processing Record 42 of Set 13 | tuskegee
# Processing Record 43 of Set 13 | trinidad
# Processing Record 44 of Set 13 | worland
# Processing Record 45 of Set 13 | ariquemes
# Processing Record 46 of Set 13 | norton shores
# Processing Record 47 of Set 13 | gilgil
# City not found. Skipping...
# Processing Record 48 of Set 13 | hamilton
# Processing Record 49 of Set 13 | berwick
# Processing Record 50 of Set 13 | port lincoln
# Processing Record 1 of Set 14 | micomeseng
# Processing Record 2 of Set 14 | mitsamiouli
# Processing Record 3 of Set 14 | warmbad
# Processing Record 4 of Set 14 | zemio
# Processing Record 5 of Set 14 | dhidhdhoo
# Processing Record 6 of Set 14 | port hardy
# Processing Record 7 of Set 14 | kroya
# Processing Record 8 of Set 14 | sarh
# Processing Record 9 of Set 14 | san quintin
# Processing Record 10 of Set 14 | ankang
# Processing Record 11 of Set 14 | kalangala
# Processing Record 12 of Set 14 | bonfim
# Processing Record 13 of Set 14 | chik ballapur
# Processing Record 14 of Set 14 | itamaraju
# Processing Record 15 of Set 14 | erenhot
# Processing Record 16 of Set 14 | esperanza
# Processing Record 17 of Set 14 | muridke
# Processing Record 18 of Set 14 | sarankhola
# Processing Record 19 of Set 14 | praia
# Processing Record 20 of Set 14 | comodoro rivadavia
# Processing Record 21 of Set 14 | komsomolskiy
# Processing Record 22 of Set 14 | derzhavinsk
# Processing Record 23 of Set 14 | warrington
# Processing Record 24 of Set 14 | bethanien
# Processing Record 25 of Set 14 | innerleithen
# Processing Record 26 of Set 14 | kurmanayevka
# Processing Record 27 of Set 14 | westport
# Processing Record 28 of Set 14 | manggar
# Processing Record 29 of Set 14 | turcianske teplice
# Processing Record 30 of Set 14 | sioux lookout
# Processing Record 31 of Set 14 | haapu
# City not found. Skipping...
# Processing Record 32 of Set 14 | nemuro
# Processing Record 33 of Set 14 | dicabisagan
# Processing Record 34 of Set 14 | eixo
# Processing Record 35 of Set 14 | phalaborwa
# Processing Record 36 of Set 14 | glinka
# Processing Record 37 of Set 14 | arrifes
# Processing Record 38 of Set 14 | kawana waters
# City not found. Skipping...
# Processing Record 39 of Set 14 | suchil
# Processing Record 40 of Set 14 | esmeraldas
# Processing Record 41 of Set 14 | guaymas
# Processing Record 42 of Set 14 | jackson
# Processing Record 43 of Set 14 | sao filipe
# Processing Record 44 of Set 14 | takoradi
# Processing Record 45 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 46 of Set 14 | nema
# Processing Record 47 of Set 14 | curaca
# Processing Record 48 of Set 14 | goderich
# Processing Record 49 of Set 14 | charlottesville
# Processing Record 50 of Set 14 | vazante
# Processing Record 1 of Set 15 | kuruman
# Processing Record 2 of Set 15 | ust-nera
# Processing Record 3 of Set 15 | lasem
# Processing Record 4 of Set 15 | asau
# Processing Record 5 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 6 of Set 15 | petrozavodsk
# Processing Record 7 of Set 15 | mongomo
# Processing Record 8 of Set 15 | washington
# Processing Record 9 of Set 15 | tazmalt
# Processing Record 10 of Set 15 | les cayes
# Processing Record 11 of Set 15 | umm lajj
# Processing Record 12 of Set 15 | nambucca heads
# Processing Record 13 of Set 15 | kashiwazaki
# Processing Record 14 of Set 15 | bayan
# Processing Record 15 of Set 15 | vanino
# Processing Record 16 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 17 of Set 15 | pyshchug
# Processing Record 18 of Set 15 | west wendover
# Processing Record 19 of Set 15 | beloha
# Processing Record 20 of Set 15 | eluru
# Processing Record 21 of Set 15 | pietermaritzburg
# Processing Record 22 of Set 15 | tezu
# Processing Record 23 of Set 15 | lushoto
# Processing Record 24 of Set 15 | eenhana
# Processing Record 25 of Set 15 | macapa
# Processing Record 26 of Set 15 | kupang
# Processing Record 27 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 28 of Set 15 | guerrero negro
# Processing Record 29 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 15 | kapit
# Processing Record 31 of Set 15 | villefranche-de-rouergue
# Processing Record 32 of Set 15 | fukue
# Processing Record 33 of Set 15 | mundgod
# Processing Record 34 of Set 15 | wajima
# Processing Record 35 of Set 15 | kapustin yar
# Processing Record 36 of Set 15 | pochutla
# Processing Record 37 of Set 15 | ranong
# Processing Record 38 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 39 of Set 15 | sinnamary
# Processing Record 40 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 15 | iroquois falls
# Processing Record 42 of Set 15 | soreang
# Processing Record 43 of Set 15 | dieppe
# Processing Record 44 of Set 15 | shagamu
# Processing Record 45 of Set 15 | guadalupe y calvo
# Processing Record 46 of Set 15 | hingatungan
# Processing Record 47 of Set 15 | ust-maya
# Processing Record 48 of Set 15 | kenora
# Processing Record 49 of Set 15 | kolvereid
# Processing Record 50 of Set 15 | yenagoa
# Processing Record 1 of Set 16 | lafia
# Processing Record 2 of Set 16 | shingu
# Processing Record 3 of Set 16 | kulachi
# Processing Record 4 of Set 16 | maumere
# Processing Record 5 of Set 16 | bose
# Processing Record 6 of Set 16 | xining
# Processing Record 7 of Set 16 | teixeira
# Processing Record 8 of Set 16 | venado tuerto
# Processing Record 9 of Set 16 | mao
# Processing Record 10 of Set 16 | homer
# Processing Record 11 of Set 16 | wawa
# Processing Record 12 of Set 16 | tanhacu
# Processing Record 13 of Set 16 | balabac
# Processing Record 14 of Set 16 | salinopolis
# Processing Record 15 of Set 16 | novyy urengoy
# Processing Record 16 of Set 16 | alyangula
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Bethel      US  41.3712  -73.4140     46.92        70          90
# 1        Airai      TL  -8.9266  125.4092     72.97        68          88
# 2    Grindavik      IS  63.8424  -22.4338     25.27        80          40
# 3      Mataura      NZ -46.1927  168.8643     59.49        38           1
# 4        Seoul      KR  37.5683  126.9778     63.79        36           0
# 5     Svetlaya      RU  46.5389  138.3297     44.92        74          85
# 6       Avarua      CK -21.2078 -159.7750     77.05        78          40
# 7       Albany      US  42.6001  -73.9662     36.09        84          14
# 8  Yellowknife      CA  62.4560 -114.3525     30.42       100           1
# 9        Vaini      TO -21.2000 -175.2000     78.96        89          40
#
#    Wind Speed Current Description
# 0        3.44     overcast clouds
# 1        3.74     overcast clouds
# 2        5.75    scattered clouds
# 3        8.68           clear sky
# 4        6.91           clear sky
# 5        8.05     overcast clouds
# 6       11.50    scattered clouds
# 7        5.68          few clouds
# 8        8.05           clear sky
# 9        9.22          light rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
